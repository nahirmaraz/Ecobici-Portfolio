# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Nahir/OneDrive/Desktop/Ecobici/badata_ecobici_recorridos_realizados_2024.csv')
print(df.columns.tolist())

# %%
df['fecha_origen_recorrido'] = pd.to_datetime(df['fecha_origen_recorrido']) 
df_enero = df[df['fecha_origen_recorrido'].dt.month == 1] 
df_enero.to_csv('C:/Users/Nahir/OneDrive/Desktop/Ecobici/ecobici_enero_2024.csv', index=False)
